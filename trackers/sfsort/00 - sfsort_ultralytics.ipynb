# %%
import os
import re
import numpy as np
import cv2
from collections import defaultdict
from random import randrange
from ultralytics import YOLO
from ultralytics.utils.torch_utils import select_device
from SFSORT import SFSORT

# %%
# Utility functions
def create_output_directory(output_path):
    try:
        os.makedirs(output_path, exist_ok=True)
        print(f"Directory created at: {output_path}")
    except OSError as e:
        print(f"Error creating directory: {e}")

def list_files(directory):
    try:
        return [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]
    except Exception as e:
        print(f"Error listing files in directory {directory}: {e}")
        return []

def get_sorted_file_paths(directory):
    files = list_files(directory)
    return [os.path.join(directory, f"frame_{i:05d}.png") for i in range(1, len(files) + 1)]

def write_mot_format(data, filename):
    try:
        with open(filename, "w") as f:
            for entry in data:
                line = "{},{},{},{},{},{},{},{},{},{}\n".format(*entry)
                f.write(line)
        print(f"MOT data written to {filename}")
    except Exception as e:
        print(f"Error writing to file {filename}: {e}")

# Core functions
def initialize_model(model_path):
    model = YOLO(model_path, 'detect')
    device = select_device('cpu')
    model.to(device)
    return model

def process_frame(frame, model, tracker, track_history, frame_id, colors):
    prediction = model.predict(frame)
    prediction_results = prediction[0].boxes.cpu().numpy()
    tracks = tracker.update(prediction_results.xyxy, prediction_results.conf)

    if len(tracks) == 0:
        return

    bbox_list = tracks[:, 0]
    track_id_list = tracks[:, 1]

    for track_id, bbox in zip(track_id_list, bbox_list):
        if track_id not in colors:
            colors[track_id] = (randrange(255), randrange(255), randrange(255))

        x0, y0, x1, y1 = map(int, bbox)
        track_history.append((frame_id, track_id, x0, y0, x1 - x0, y1 - y0, -1, -1, -1, -1))

def process_video(dir_images, model, tracker, output_file):
    files_sorted = get_sorted_file_paths(dir_images)
    track_history = []
    colors = {}

    for file in files_sorted:
        match = re.search(r'frame_\d+\.png', file)
        if not match:
            continue

        frame_id = int(match.group(0).split("_")[1].split(".")[0])
        frame = cv2.imread(file)
        process_frame(frame, model, tracker, track_history, frame_id, colors)

    write_mot_format(track_history, output_file)

# %%
# Global constants
ALGORITHM = "sfsort"
MODEL_NAME = "yolo11n_DJI_0008_V_and_0010_V_2@fine-tuning" #"yolo11x_DJI_0008_V_and_0010_V_2@fine-tuning" # yolo11n_DJI_0010_V_2@fine-tuning yolo11n_DJI_0008_V@fine-tuning
OUTPUT_PATH_MOT_FILES = f'../../output/mot_detections/{ALGORITHM}'
FRAME_RATE = 25
FRAME_WIDTH = 1920
FRAME_HEIGHT = 1088

TRACKER_ARGUMENTS = {
    "dynamic_tuning": True,
    "cth": 0.7,
    "high_th": 0.82,
    "high_th_m": 0.1,
    "match_th_first": 0.5,
    "match_th_first_m": 0.05,
    "match_th_second": 0.1,
    "low_th": 0.3,
    "new_track_th": 0.7,
    "new_track_th_m": 0.1,
    "marginal_timeout": (7 * FRAME_RATE // 10),
    "central_timeout": FRAME_RATE,
    "horizontal_margin": FRAME_WIDTH // 10,
    "vertical_margin": FRAME_HEIGHT // 10,
    "frame_width": FRAME_WIDTH,
    "frame_height": FRAME_HEIGHT
}

create_output_directory(OUTPUT_PATH_MOT_FILES)

# %%
name_video = "DJI_20240308111117_0010_V_1"
model_path = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/weights/{MODEL_NAME}/best.pt"
dir_images = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/dataset/{name_video}/valid/images"
output_dir = os.path.join(OUTPUT_PATH_MOT_FILES, f"{MODEL_NAME}@{name_video}")
output_file = os.path.join(output_dir, f"{name_video}.txt")

create_output_directory(output_dir)

model = initialize_model(model_path)
tracker = SFSORT(TRACKER_ARGUMENTS)

process_video(dir_images, model, tracker, output_file)

# %%
name_video = "DJI_20240308110228_0006_V_2"
model_path = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/weights/{MODEL_NAME}/best.pt"
dir_images = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/dataset/{name_video}/valid/images"
output_dir = os.path.join(OUTPUT_PATH_MOT_FILES, f"{MODEL_NAME}@{name_video}")
output_file = os.path.join(output_dir, f"{name_video}.txt")

create_output_directory(output_dir)

model = initialize_model(model_path)
tracker = SFSORT(TRACKER_ARGUMENTS)

process_video(dir_images, model, tracker, output_file)

# %%
name_video = "DJI_20240308110115_0005_V"
model_path = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/weights/{MODEL_NAME}/best.pt"
dir_images = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/dataset/{name_video}/valid/images"
output_dir = os.path.join(OUTPUT_PATH_MOT_FILES, f"{MODEL_NAME}@{name_video}")
output_file = os.path.join(output_dir, f"{name_video}.txt")

create_output_directory(output_dir)

model = initialize_model(model_path)
tracker = SFSORT(TRACKER_ARGUMENTS)

process_video(dir_images, model, tracker, output_file)

# %%
name_video = "DJI_20240308110013_0004_V_1"
model_path = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/weights/{MODEL_NAME}/best.pt"
dir_images = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/dataset/{name_video}/valid/images"
output_dir = os.path.join(OUTPUT_PATH_MOT_FILES, f"{MODEL_NAME}@{name_video}")
output_file = os.path.join(output_dir, f"{name_video}.txt")

create_output_directory(output_dir)

model = initialize_model(model_path)
tracker = SFSORT(TRACKER_ARGUMENTS)

process_video(dir_images, model, tracker, output_file)

# %%
name_video = "DJI_20240308110013_0004_V_3"
model_path = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/weights/{MODEL_NAME}/best.pt"
dir_images = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/dataset/{name_video}/valid/images"
output_dir = os.path.join(OUTPUT_PATH_MOT_FILES, f"{MODEL_NAME}@{name_video}")
output_file = os.path.join(output_dir, f"{name_video}.txt")

create_output_directory(output_dir)

model = initialize_model(model_path)
tracker = SFSORT(TRACKER_ARGUMENTS)

process_video(dir_images, model, tracker, output_file)
# Out:
# 0: 384x640 10 pineapples, 230.8ms
# Speed: 5.0ms preprocess, 230.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 190.2ms
# Speed: 4.9ms preprocess, 190.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 175.3ms
# Speed: 5.4ms preprocess, 175.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 pineapples, 169.6ms
# Speed: 5.9ms preprocess, 169.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 pineapples, 170.0ms
# Speed: 0.0ms preprocess, 170.0ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 pineapples, 210.1ms
# Speed: 2.8ms preprocess, 210.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 pineapples, 195.9ms
# Speed: 2.8ms preprocess, 195.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 pineapples, 165.8ms
# Speed: 0.0ms preprocess, 165.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 pineapples, 162.0ms
# Speed: 0.0ms preprocess, 162.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 207.0ms
# Speed: 14.5ms preprocess, 207.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 pineapples, 239.0ms
# Speed: 14.3ms preprocess, 239.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 208.6ms
# Speed: 0.0ms preprocess, 208.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 246.1ms
# Speed: 3.5ms preprocess, 246.1ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 pineapples, 427.4ms
# Speed: 10.5ms preprocess, 427.4ms inference, 19.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 269.6ms
# Speed: 10.5ms preprocess, 269.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 168.9ms
# Speed: 9.7ms preprocess, 168.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 185.5ms
# Speed: 0.0ms preprocess, 185.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 191.4ms
# Speed: 0.0ms preprocess, 191.4ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 pineapples, 174.2ms
# Speed: 0.0ms preprocess, 174.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 158.3ms
# Speed: 16.6ms preprocess, 158.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 pineapples, 211.4ms
# Speed: 0.0ms preprocess, 211.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 131.2ms
# Speed: 0.0ms preprocess, 131.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 pineapples, 204.9ms
# Speed: 1.2ms preprocess, 204.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 pineapples, 249.7ms
# Speed: 17.6ms preprocess, 249.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 pineapples, 317.3ms
# Speed: 19.5ms preprocess, 317.3ms inference, 14.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 pineapples, 172.5ms
# Speed: 2.2ms preprocess, 172.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 157.9ms
# Speed: 0.0ms preprocess, 157.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 172.1ms
# Speed: 16.5ms preprocess, 172.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 158.4ms
# Speed: 0.0ms preprocess, 158.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 pineapples, 175.0ms
# Speed: 0.0ms preprocess, 175.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 159.0ms
# Speed: 0.0ms preprocess, 159.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 175.4ms
# Speed: 15.6ms preprocess, 175.4ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 194.8ms
# Speed: 1.0ms preprocess, 194.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 206.2ms
# Speed: 0.0ms preprocess, 206.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 pineapples, 153.6ms
# Speed: 0.0ms preprocess, 153.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 pineapples, 229.2ms
# Speed: 10.5ms preprocess, 229.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 pineapples, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 pineapples, 158.1ms
# Speed: 0.0ms preprocess, 158.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 143.7ms
# Speed: 15.7ms preprocess, 143.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 197.7ms
# Speed: 5.0ms preprocess, 197.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 310.2ms
# Speed: 0.0ms preprocess, 310.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pineapple, 270.4ms
# Speed: 15.6ms preprocess, 270.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pineapple, 213.2ms
# Speed: 0.0ms preprocess, 213.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pineapple, 222.4ms
# Speed: 0.0ms preprocess, 222.4ms inference, 17.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 223.0ms
# Speed: 0.0ms preprocess, 223.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pineapple, 206.4ms
# Speed: 15.6ms preprocess, 206.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pineapple, 225.9ms
# Speed: 0.0ms preprocess, 225.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pineapple, 216.8ms
# Speed: 15.1ms preprocess, 216.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pineapple, 206.4ms
# Speed: 0.0ms preprocess, 206.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 207.1ms
# Speed: 8.6ms preprocess, 207.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 230.0ms
# Speed: 0.0ms preprocess, 230.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 299.9ms
# Speed: 0.0ms preprocess, 299.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 221.8ms
# Speed: 0.0ms preprocess, 221.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 234.3ms
# Speed: 18.6ms preprocess, 234.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 253.4ms
# Speed: 15.7ms preprocess, 253.4ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 207.4ms
# Speed: 3.0ms preprocess, 207.4ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 268.9ms
# Speed: 0.0ms preprocess, 268.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 253.4ms
# Speed: 0.0ms preprocess, 253.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 253.7ms
# Speed: 0.0ms preprocess, 253.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 238.5ms
# Speed: 0.0ms preprocess, 238.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 225.4ms
# Speed: 0.0ms preprocess, 225.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 221.9ms
# Speed: 15.2ms preprocess, 221.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 218.0ms
# Speed: 16.8ms preprocess, 218.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# MOT data written to ../../output/mot_detections/sfsort\yolo11n_DJI_0008_V_and_0010_V_2@fine-tuning@DJI_20240308110013_0004_V_3\DJI_20240308110013_0004_V_3.txt
