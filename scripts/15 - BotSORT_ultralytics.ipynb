# %%
import os
import cv2
import re
from ultralytics import YOLO
from collections import defaultdict

# %%
# Function to list files in a directory
def list_files(directory):
    try:
        return [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]
    except Exception as e:
        return str(e)  # Return the error message as a string

# Function to list directories in a given path
def list_directories(path='.'): 
    return [d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))]

# Function to sort files by frame number
def get_sorted_file_paths(directory):
    path_mot_dataset = directory 
    files_sorted = []
    for i in range(1, len(list_files(path_mot_dataset)) + 1):
        files_sorted.append(os.path.join(path_mot_dataset, f"frame_{i:05d}.png"))
    return files_sorted

# Function to process frames and generate tracking history
def process_frames(files_sorted, model_path):
    model = YOLO(model_path)
    track_history = []

    for file in files_sorted:
        frame = cv2.imread(file)
        results = model.track(frame, persist=True, tracker="botsort.yaml")

        if results[0].boxes.id is None:
            continue

        match = re.search(r'frame_\d+\.png', file)
        if match:
            frame_file = match.group(0)
            frame_id = int(frame_file.split(".")[0].split("_")[1])

            for _, result in enumerate(results):
                for box in result.boxes:
                    bbox = box.xyxy[0].tolist()  # Convert from tensor to list
                    track_id = box.id.item()  # Get track ID
                    conf = box.conf.item()  # Get confidence score
                    track_history.append((
                        frame_id, track_id, bbox[0], bbox[1], bbox[2] - bbox[0], bbox[3] - bbox[1], conf, -1, -1, -1
                    ))
    return track_history

# Function to write tracking history to a MOT format file
def write_mot_format(data, filename):
    with open(filename, "w") as f:
        for entry in data:
            line = "{},{},{},{},{},{},{},{},{},{}\n".format(*entry)
            f.write(line)

# Function to create output directories
def create_output_directory(output_path):
    try:
        os.makedirs(output_path, exist_ok=True)
        print(f"Directory created at: {output_path}")
    except OSError as e:
        print(f"Error creating directory: {e}")

# %%
# Define global constants
ALGORITHM = "botsort"
MODEL_NAME = "yolo11x_DJI_0010_V_2@fine-tuning" #yolo11n_DJI_0008_V@fine-tuning # yolo11n_DJI_0008_V_and_0010_V_2@fine-tuning
# yolo11x_DJI_0008_V_and_0010_V_2@fine-tuning yolo11x_DJI_0010_V_2@fine-tuning
OUTPUT_PATH_MOT_FILES = f'../output/mot_detections/{ALGORITHM}'

# %%
name_video = "DJI_20240308111117_0010_V_1"
model_path = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/weights/{MODEL_NAME}/best.pt"
dir_images = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/dataset/{name_video}/valid/images"

output_file = os.path.join(OUTPUT_PATH_MOT_FILES, f"{MODEL_NAME}@{name_video}", "output.txt")

# Create output directory
create_output_directory(os.path.join(OUTPUT_PATH_MOT_FILES, f"{MODEL_NAME}@{name_video}"))

# Get sorted file paths
files_sorted = get_sorted_file_paths(dir_images)

# Process frames and get tracking history
track_history = process_frames(files_sorted, model_path)

# Write tracking history to MOT format file
write_mot_format(track_history, output_file)

# %%
name_video = "DJI_20240308110228_0006_V_2"
model_path = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/weights/{MODEL_NAME}/best.pt"
dir_images = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/dataset/{name_video}/valid/images"

output_file = os.path.join(OUTPUT_PATH_MOT_FILES, f"{MODEL_NAME}@{name_video}", "output.txt")

# Create output directory
create_output_directory(os.path.join(OUTPUT_PATH_MOT_FILES, f"{MODEL_NAME}@{name_video}"))

# Get sorted file paths
files_sorted = get_sorted_file_paths(dir_images)

# Process frames and get tracking history
track_history = process_frames(files_sorted, model_path)

# Write tracking history to MOT format file
write_mot_format(track_history, output_file)

# %%
name_video = "DJI_20240308110115_0005_V"
model_path = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/weights/{MODEL_NAME}/best.pt"
dir_images = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/dataset/{name_video}/valid/images"

output_file = os.path.join(OUTPUT_PATH_MOT_FILES, f"{MODEL_NAME}@{name_video}", "output.txt")

# Create output directory
create_output_directory(os.path.join(OUTPUT_PATH_MOT_FILES, f"{MODEL_NAME}@{name_video}"))

# Get sorted file paths
files_sorted = get_sorted_file_paths(dir_images)

# Process frames and get tracking history
track_history = process_frames(files_sorted, model_path)

# Write tracking history to MOT format file
write_mot_format(track_history, output_file)
# Out:
# 0: 384x640 13 pineapples, 2625.0ms
# Speed: 15.5ms preprocess, 2625.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 2024.1ms
# Speed: 6.0ms preprocess, 2024.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 1911.5ms
# Speed: 5.3ms preprocess, 1911.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 1940.6ms
# Speed: 6.0ms preprocess, 1940.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 2068.9ms
# Speed: 6.8ms preprocess, 2068.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 2078.9ms
# Speed: 6.1ms preprocess, 2078.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 pineapples, 1841.4ms
# Speed: 15.7ms preprocess, 1841.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 pineapples, 1899.6ms
# Speed: 5.3ms preprocess, 1899.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 1937.8ms
# Speed: 5.0ms preprocess, 1937.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 pineapples, 2030.7ms
# Speed: 5.0ms preprocess, 2030.7ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 2857.4ms
# Speed: 5.4ms preprocess, 2857.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 2814.7ms
# Speed: 15.5ms preprocess, 2814.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 2149.9ms
# Speed: 9.0ms preprocess, 2149.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 pineapples, 2070.7ms
# Speed: 5.6ms preprocess, 2070.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 1988.3ms
# Speed: 23.3ms preprocess, 1988.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 pineapples, 2638.2ms
# Speed: 6.0ms preprocess, 2638.2ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 2557.4ms
# Speed: 5.4ms preprocess, 2557.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 pineapples, 2412.3ms
# Speed: 6.4ms preprocess, 2412.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 2208.5ms
# Speed: 8.4ms preprocess, 2208.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 2129.1ms
# Speed: 0.0ms preprocess, 2129.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 2047.6ms
# Speed: 6.6ms preprocess, 2047.6ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 2091.7ms
# Speed: 5.0ms preprocess, 2091.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 2019.0ms
# Speed: 6.0ms preprocess, 2019.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 2061.7ms
# Speed: 10.1ms preprocess, 2061.7ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 2057.8ms
# Speed: 7.5ms preprocess, 2057.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 pineapples, 2050.2ms
# Speed: 6.2ms preprocess, 2050.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 1982.1ms
# Speed: 15.3ms preprocess, 1982.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 2193.1ms
# Speed: 4.0ms preprocess, 2193.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 2104.8ms
# Speed: 20.2ms preprocess, 2104.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 pineapples, 2086.0ms
# Speed: 7.7ms preprocess, 2086.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 pineapples, 2095.8ms
# Speed: 5.0ms preprocess, 2095.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 pineapples, 2066.8ms
# Speed: 10.4ms preprocess, 2066.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 pineapples, 2062.9ms
# Speed: 6.0ms preprocess, 2062.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 pineapples, 2205.0ms
# Speed: 5.9ms preprocess, 2205.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 2295.1ms
# Speed: 6.7ms preprocess, 2295.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 pineapples, 3011.9ms
# Speed: 9.3ms preprocess, 3011.9ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 2212.1ms
# Speed: 7.6ms preprocess, 2212.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 1984.1ms
# Speed: 4.9ms preprocess, 1984.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 1922.1ms
# Speed: 6.0ms preprocess, 1922.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 2075.6ms
# Speed: 5.9ms preprocess, 2075.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 pineapples, 2119.2ms
# Speed: 7.4ms preprocess, 2119.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 2181.8ms
# Speed: 5.6ms preprocess, 2181.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 2038.5ms
# Speed: 7.6ms preprocess, 2038.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 2004.0ms
# Speed: 4.4ms preprocess, 2004.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 
3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1638.9ms
# Speed: 17.7ms preprocess, 1638.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2029.7ms
# Speed: 6.4ms preprocess, 2029.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1649.3ms
# Speed: 5.0ms preprocess, 1649.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1649.2ms
# Speed: 3.0ms preprocess, 1649.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1557.0ms
# Speed: 7.5ms preprocess, 1557.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1451.4ms
# Speed: 9.1ms preprocess, 1451.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1526.6ms
# Speed: 5.0ms preprocess, 1526.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1650.1ms
# Speed: 3.9ms preprocess, 1650.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1495.3ms
# Speed: 3.4ms preprocess, 1495.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1478.8ms
# Speed: 5.0ms preprocess, 1478.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1395.0ms
# Speed: 0.0ms preprocess, 1395.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1468.7ms
# Speed: 6.9ms preprocess, 1468.7ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1549.2ms
# Speed: 3.7ms preprocess, 1549.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 pineapple, 1441.3ms
# Speed: 0.0ms preprocess, 1441.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 pineapples, 1806.2ms
# Speed: 6.5ms preprocess, 1806.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 pineapples, 1541.3ms
# Speed: 15.7ms preprocess, 1541.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 pineapples, 1916.6ms
# Speed: 4.4ms preprocess, 1916.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 pineapples, 1505.7ms
# Speed: 6.4ms preprocess, 1505.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 pineapples, 1697.5ms
# Speed: 6.0ms preprocess, 1697.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 1842.3ms
# Speed: 10.4ms preprocess, 1842.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 1740.4ms
# Speed: 0.0ms preprocess, 1740.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 1697.1ms
# Speed: 4.7ms preprocess, 1697.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 1816.8ms
# Speed: 3.4ms preprocess, 1816.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 1594.2ms
# Speed: 3.7ms preprocess, 1594.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 1878.1ms
# Speed: 4.7ms preprocess, 1878.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 pineapples, 2092.6ms
# Speed: 11.7ms preprocess, 2092.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 pineapples, 2224.6ms
# Speed: 5.2ms preprocess, 2224.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 pineapples, 1746.1ms
# Speed: 9.8ms preprocess, 1746.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 pineapples, 1550.2ms
# Speed: 0.0ms preprocess, 1550.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 pineapples, 1557.5ms
# Speed: 0.0ms preprocess, 1557.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 pineapples, 1841.3ms
# Speed: 7.0ms preprocess, 1841.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 pineapples, 1714.6ms
# Speed: 2.5ms preprocess, 1714.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 pineapples, 1559.3ms
# Speed: 4.1ms preprocess, 1559.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 pineapples, 1504.2ms
# Speed: 0.0ms preprocess, 1504.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 pineapples, 1620.0ms
# Speed: 0.0ms preprocess, 1620.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 pineapples, 2163.4ms
# Speed: 6.1ms preprocess, 2163.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 pineapples, 2803.2ms
# Speed: 5.5ms preprocess, 2803.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 pineapples, 2517.1ms
# Speed: 13.0ms preprocess, 2517.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 pineapples, 2903.5ms
# Speed: 11.7ms preprocess, 2903.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 pineapples, 3487.2ms
# Speed: 8.9ms preprocess, 3487.2ms inference, 51.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 pineapples, 4420.4ms
# Speed: 35.7ms preprocess, 4420.4ms inference, 80.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 pineapples, 4926.1ms
# Speed: 63.2ms preprocess, 4926.1ms inference, 315.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 pineapples, 1606.9ms
# Speed: 17.9ms preprocess, 1606.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 pineapples, 1979.6ms
# Speed: 5.0ms preprocess, 1979.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 pineapples, 2230.6ms
# Speed: 10.1ms preprocess, 2230.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 pineapples, 2400.4ms
# Speed: 7.5ms preprocess, 2400.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 pineapples, 2362.4ms
# Speed: 5.7ms preprocess, 2362.4ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 pineapples, 2176.0ms
# Speed: 6.0ms preprocess, 2176.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 pineapples, 2067.8ms
# Speed: 9.9ms preprocess, 2067.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 pineapples, 1932.9ms
# Speed: 7.0ms preprocess, 1932.9ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 pineapples, 2825.8ms
# Speed: 79.2ms preprocess, 2825.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 pineapples, 2338.0ms
# Speed: 9.5ms preprocess, 2338.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 pineapples, 2721.3ms
# Speed: 8.6ms preprocess, 2721.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 pineapples, 2062.3ms
# Speed: 5.5ms preprocess, 2062.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 pineapples, 1892.4ms
# Speed: 7.0ms preprocess, 1892.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 pineapples, 2054.5ms
# Speed: 4.0ms preprocess, 2054.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 pineapples, 1796.0ms
# Speed: 7.8ms preprocess, 1796.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 pineapples, 1891.9ms
# Speed: 6.1ms preprocess, 1891.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 pineapples, 3053.5ms
# Speed: 6.0ms preprocess, 3053.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 pineapples, 3670.4ms
# Speed: 5.5ms preprocess, 3670.4ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 pineapples, 4056.6ms
# Speed: 42.1ms preprocess, 4056.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 pineapples, 4341.2ms
# Speed: 114.9ms preprocess, 4341.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 pineapples, 3744.7ms
# Speed: 5.2ms preprocess, 3744.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3393.9ms
# Speed: 10.0ms preprocess, 3393.9ms inference, 18.9ms postprocess per image at shape (1, 3, 384, 640)

# %%
name_video = "DJI_20240308110013_0004_V_1"
model_path = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/weights/{MODEL_NAME}/best.pt"
dir_images = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/dataset/{name_video}/valid/images"

output_file = os.path.join(OUTPUT_PATH_MOT_FILES, f"{MODEL_NAME}@{name_video}", "output.txt")

# Create output directory
create_output_directory(os.path.join(OUTPUT_PATH_MOT_FILES, f"{MODEL_NAME}@{name_video}"))

# Get sorted file paths
files_sorted = get_sorted_file_paths(dir_images)

# Process frames and get tracking history
track_history = process_frames(files_sorted, model_path)

# Write tracking history to MOT format file
write_mot_format(track_history, output_file)
# Out:
# Directory created at: ../output/mot_detections/botsort\yolo11x_DJI_0010_V_2@fine-tuning@DJI_20240308110013_0004_V_1
#
# 0: 384x640 11 pineapples, 2921.7ms
# Speed: 6.0ms preprocess, 2921.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 1985.4ms
# Speed: 8.5ms preprocess, 1985.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 2617.6ms
# Speed: 8.0ms preprocess, 2617.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3699.3ms
# Speed: 7.5ms preprocess, 3699.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 4594.2ms
# Speed: 11.9ms preprocess, 4594.2ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 3646.1ms
# Speed: 10.6ms preprocess, 3646.1ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 3310.9ms
# Speed: 9.0ms preprocess, 3310.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 3050.9ms
# Speed: 7.0ms preprocess, 3050.9ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 2887.6ms
# Speed: 5.0ms preprocess, 2887.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 3750.7ms
# Speed: 7.0ms preprocess, 3750.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 3255.6ms
# Speed: 42.4ms preprocess, 3255.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 3023.5ms
# Speed: 5.6ms preprocess, 3023.5ms inference, 18.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 3239.2ms
# Speed: 13.1ms preprocess, 3239.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 1895.7ms
# Speed: 7.0ms preprocess, 1895.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 2211.2ms
# Speed: 4.0ms preprocess, 2211.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3432.0ms
# Speed: 10.0ms preprocess, 3432.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3628.3ms
# Speed: 6.0ms preprocess, 3628.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3321.4ms
# Speed: 10.3ms preprocess, 3321.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3519.8ms
# Speed: 8.2ms preprocess, 3519.8ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3493.9ms
# Speed: 42.1ms preprocess, 3493.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 3384.3ms
# Speed: 8.4ms preprocess, 3384.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 pineapples, 3043.4ms
# Speed: 23.5ms preprocess, 3043.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 4276.7ms
# Speed: 14.8ms preprocess, 4276.7ms inference, 167.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 3022.2ms
# Speed: 34.4ms preprocess, 3022.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 3575.5ms
# Speed: 11.2ms preprocess, 3575.5ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 pineapples, 4044.1ms
# Speed: 7.0ms preprocess, 4044.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 pineapples, 3335.1ms
# Speed: 7.0ms preprocess, 3335.1ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 2402.0ms
# Speed: 67.4ms preprocess, 2402.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 6509.5ms
# Speed: 9.5ms preprocess, 6509.5ms inference, 465.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 4043.2ms
# Speed: 18.0ms preprocess, 4043.2ms inference, 27.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3849.7ms
# Speed: 8.9ms preprocess, 3849.7ms inference, 66.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 4003.8ms
# Speed: 33.1ms preprocess, 4003.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3956.5ms
# Speed: 8.0ms preprocess, 3956.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3197.6ms
# Speed: 56.1ms preprocess, 3197.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 4042.5ms
# Speed: 5.0ms preprocess, 4042.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 4064.0ms
# Speed: 8.0ms preprocess, 4064.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 3551.6ms
# Speed: 8.0ms preprocess, 3551.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 4354.3ms
# Speed: 24.4ms preprocess, 4354.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 pineapples, 3785.0ms
# Speed: 15.8ms preprocess, 3785.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 2468.5ms
# Speed: 8.0ms preprocess, 2468.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 2486.0ms
# Speed: 9.6ms preprocess, 2486.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 4001.8ms
# Speed: 40.8ms preprocess, 4001.8ms inference, 60.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 3982.8ms
# Speed: 9.0ms preprocess, 3982.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 4636.1ms
# Speed: 10.0ms preprocess, 4636.1ms inference, 62.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3676.3ms
# Speed: 93.5ms preprocess, 3676.3ms inference, 65.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 3436.9ms
# Speed: 7.0ms preprocess, 3436.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 3277.0ms
# Speed: 6.0ms preprocess, 3277.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 2920.8ms
# Speed: 7.6ms preprocess, 2920.8ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3405.0ms
# Speed: 59.4ms preprocess, 3405.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3667.5ms
# Speed: 19.0ms preprocess, 3667.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 3370.7ms
# Speed: 22.5ms preprocess, 3370.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 pineapples, 3060.0ms
# Speed: 7.0ms preprocess, 3060.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 pineapples, 2066.2ms
# Speed: 8.0ms preprocess, 2066.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 pineapples, 2171.5ms
# Speed: 5.0ms preprocess, 2171.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 pineapples, 3854.7ms
# Speed: 7.0ms preprocess, 3854.7ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 pineapples, 4084.3ms
# Speed: 8.5ms preprocess, 4084.3ms inference, 191.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 3997.0ms
# Speed: 2937.8ms preprocess, 3997.0ms inference, 358.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 3010.2ms
# Speed: 9.2ms preprocess, 3010.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 pineapples, 3076.1ms
# Speed: 8.0ms preprocess, 3076.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 pineapples, 2677.7ms
# Speed: 10.4ms preprocess, 2677.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3065.7ms
# Speed: 7.0ms preprocess, 3065.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3306.3ms
# Speed: 8.0ms preprocess, 3306.3ms inference, 22.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3238.2ms
# Speed: 8.0ms preprocess, 3238.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3169.1ms
# Speed: 66.9ms preprocess, 3169.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 3090.9ms
# Speed: 7.0ms preprocess, 3090.9ms inference, 28.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 1894.6ms
# Speed: 12.8ms preprocess, 1894.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 1443.0ms
# Speed: 7.0ms preprocess, 1443.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 2429.1ms
# Speed: 13.5ms preprocess, 2429.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 3038.7ms
# Speed: 5.1ms preprocess, 3038.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 2620.5ms
# Speed: 5.4ms preprocess, 2620.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 2989.4ms
# Speed: 6.0ms preprocess, 2989.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 2731.1ms
# Speed: 6.0ms preprocess, 2731.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 2782.6ms
# Speed: 6.0ms preprocess, 2782.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 2391.8ms
# Speed: 19.8ms preprocess, 2391.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 2296.0ms
# Speed: 6.0ms preprocess, 2296.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 2418.1ms
# Speed: 6.0ms preprocess, 2418.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 2444.2ms
# Speed: 6.0ms preprocess, 2444.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 2180.0ms
# Speed: 6.5ms preprocess, 2180.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 2277.2ms
# Speed: 9.0ms preprocess, 2277.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 1451.2ms
# Speed: 5.0ms preprocess, 1451.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 1916.9ms
# Speed: 4.0ms preprocess, 1916.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 2801.1ms
# Speed: 7.7ms preprocess, 2801.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 3087.4ms
# Speed: 10.2ms preprocess, 3087.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 3235.4ms
# Speed: 24.5ms preprocess, 3235.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 3526.0ms
# Speed: 11.6ms preprocess, 3526.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 2651.5ms
# Speed: 0.0ms preprocess, 2651.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 2329.5ms
# Speed: 9.0ms preprocess, 2329.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 2391.1ms
# Speed: 0.0ms preprocess, 2391.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 2880.3ms
# Speed: 15.7ms preprocess, 2880.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 2328.0ms
# Speed: 16.1ms preprocess, 2328.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 2562.0ms
# Speed: 14.0ms preprocess, 2562.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 2441.7ms
# Speed: 14.0ms preprocess, 2441.7ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 1498.7ms
# Speed: 2.9ms preprocess, 1498.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 pineapples, 2222.4ms
# Speed: 0.0ms preprocess, 2222.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 3367.7ms
# Speed: 5.7ms preprocess, 3367.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 4001.8ms
# Speed: 11.0ms preprocess, 4001.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 2584.5ms
# Speed: 7.0ms preprocess, 2584.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 pineapples, 2644.1ms
# Speed: 7.0ms preprocess, 2644.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 pineapples, 2799.6ms
# Speed: 7.0ms preprocess, 2799.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 2398.7ms
# Speed: 15.6ms preprocess, 2398.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 pineapples, 2801.3ms
# Speed: 12.6ms preprocess, 2801.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 pineapples, 2735.2ms
# Speed: 0.0ms preprocess, 2735.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 pineapples, 2790.5ms
# Speed: 0.0ms preprocess, 2790.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 pineapples, 2514.4ms
# Speed: 18.8ms preprocess, 2514.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 2058.9ms
# Speed: 15.6ms preprocess, 2058.9ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 1435.2ms
# Speed: 0.0ms preprocess, 1435.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 pineapples, 2192.6ms
# Speed: 4.0ms preprocess, 2192.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 4093.2ms
# Speed: 0.0ms preprocess, 4093.2ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 4325.9ms
# Speed: 41.8ms preprocess, 4325.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 pineapples, 3249.1ms
# Speed: 8.7ms preprocess, 3249.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 3605.0ms
# Speed: 7.0ms preprocess, 3605.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 pineapples, 2638.2ms
# Speed: 7.9ms preprocess, 2638.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
name_video = "DJI_20240308110013_0004_V_3"
model_path = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/weights/{MODEL_NAME}/best.pt"
dir_images = f"C:/Users/dnnxl/Documents/GitHub/drone-sort/dataset/{name_video}/valid/images"

output_file = os.path.join(OUTPUT_PATH_MOT_FILES, f"{MODEL_NAME}@{name_video}", "output.txt")

# Create output directory
create_output_directory(os.path.join(OUTPUT_PATH_MOT_FILES, f"{MODEL_NAME}@{name_video}"))

# Get sorted file paths
files_sorted = get_sorted_file_paths(dir_images)

# Process frames and get tracking history
track_history = process_frames(files_sorted, model_path)

# Write tracking history to MOT format file
write_mot_format(track_history, output_file)
